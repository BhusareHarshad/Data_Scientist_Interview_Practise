# %% [markdown]
# <a href="https://colab.research.google.com/github/BhusareHarshad/Data_Scientist_Interview_Practise/blob/main/Scipy_Stats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Binomial probability calculation

# %%
from scipy.stats import binom


k, n, p = 4, 20, 0.15

prob = binom.cdf(k, n, p)

print(f"Probability: {prob:.4f}")
# Out:
# Probability: 0.8298

# %%
1- prob
# Out:
# np.float64(0.1701531537313461)

# %%
binom.pmf(k=3, n=20, p=0.15)
# Out:
# np.float64(0.24282889614926753)

# %% [markdown]
# ### Poisson Distribution

# %%
from scipy.stats import poisson

# %%
poisson.pmf(k=7, mu=5)
# Out:
# np.float64(0.10444486295705395)

# %%
poisson.pmf(k=3, mu=5) + poisson.pmf(k=2, mu=5) + poisson.pmf(k=1, mu=5)
# Out:
# np.float64(0.25828796829827616)

# %%
1-0.258
# Out:
# 0.742

# %%
poisson.pmf(k=1, mu=0.15)
# Out:
# np.float64(0.12910619646375868)

# %%
poisson.pmf(k=0, mu=4) + poisson.pmf(k=1, mu=4)
# Out:
# np.float64(0.09157819444367091)

# %%
p=0
for i in range(26):
  p += poisson.pmf(k=i, mu=20)

# %%
1-p
# Out:
# np.float64(0.11218497271797323)

# %%
import random
random.seed(42)

population = [random.expovariate(0.2) for _ in range(10000)]

print(population)
# Out:
# [5.1003014363740045, 0.12664419521369444, 1.6081203203748278, 1.2629309283505676, 6.667963364040414, 5.645865043992964, 11.136440497756903, 0.4547620230328307, 2.7402307969824546, 0.15125088603679293, 1.2335834797991214, 3.519577639330767, 0.1344720184015388, 1.108458345818402, 5.247460006112862, 3.936646271212006, 1.2451320948341182, 4.4490435315088135, 8.288690471115485, 0.03259984277133384, 8.194829310452757, 5.988949704867426, 2.0794754324929046, 0.844931340436349, 15.757613242191521, 2.0518446494054166, 0.48666325669978683, 0.5085934249781582, 9.402768708165693, 4.628247334780074, 8.228649697026292, 6.541702152231334, 3.841812120150846, 18.081075928450094, 2.378373414244923, 4.015263727432424, 8.84230492292751, 4.818481025634237, 9.891899676717074, 4.306079706744229, 6.0966478612391555, 0.23453770128443882, 1.2931948517358267, 1.7081432858984018, 0.4157776122949507, 1.324979381960011, 0.5323691725573976, 1.6284678998414703, 5.048674377672412, 2.269330149600577, 2.3116137512622235, 1.1754925822687063, 1.5528966056999327, 13.795763966727641, 5.221123173529378, 4.696914139981339, 0.9385119267955727, 6.530522283561917, 0.8920610040397212, 2.3857893334717417, 22.793031842210308, 5.1082529023011976, 4.070360350837315, 5.769793946676929, 9.252833673237534, 7.4805441612216965, 1.3006462875532705, 0.16313377410069696, 1.8949902177933435, 1.5581041654670402, 1.1848360693432443, 14.31560652626729, 10.452214232559482, 1.889331521209327, 5.327415822964918, 2.5178591567379542, 12.298978315770652, 3.070310988368078, 1.538608771402588, 1.4159774789884356, 4.120473960553504, 1.524084246095957, 4.3923982105915975, 11.405237681443937, 2.5491348224643167, 1.2379545832520849, 30.033107162992387, 3.5619180363895833, 0.4765526659778029, 0.24131248802947106, 0.5806982919265748, 4.936866985822861, 7.852994157652353, 2.742291038918248, 0.3281767116074572, 2.403254849742024, 27.761379603091456, 3.765699926752331, 17.715828920754486, 9.858488622156097, 0.05773718855937926, 6.377734653365208, 5.723967607470929, 3.8498207287925377, 1.5518555989431917, 5.1216324275693275, 0.5913967704868394, 2.8525707429225293, 3.0231519943217067, 15.375601459367243, 10.431442256928557, 1.5284770525131233, 3.47160047127477, 0.9840412027879006, 12.18789287517116, 10.221089022738525, 1.7722784091082648, 5.093687135082791, 4.694857681593116, 0.8293241837422347, 7.188165652710259, 3.875898826594374, 7.539519311018991, 3.7788768078803616, 0.0028602986145497117, 1.958965415735829, 0.09834456734910403, 13.23232664457711, 10.54834420289263, 8.909011910637446, 1.8373371941102659, 0.2983528323603866, 10.519064596724018, 14.682549788827886, 0.4477281205120214, 3.3275672992018226, 0.3586214839698608, 7.148142652077943, 7.258634233839185, 0.6870744152487938, 3.2244751206796587, 3.9903566626906355, 1.5398091445723032, 10.295569421386608, 2.750760527637223, 1.190005687219623, 3.874998586710563, 6.5453902645021085, 1.122917083300457, 1.8677707937680448, 26.64321967795698, 5.247368892168976, 2.882157651023164, 3.6446577702558423, 0.6448757738242777, 1.272508965021967, 2.0630948967762346, 4.437407635772084, 1.3075688930434537, 1.243700480784142, 0.3681954889726054, 4.986188454331153, 1.2999570044540871, 11.79154689640493, 9.817559788710724, 0.3674649981486006, 1.3590740258153018, 5.527848854009886, 1.205499067945708, 0.7096145080018875, 13.706554318766392, 4.2319940787065615, 3.1996534334951807, 7.676743480459541, 8.238217646792389, 1.0561361326213092, 0.5097805540667041, 2.819824002033713, 2.754581642433708, 3.1464006869100682, 6.529581922919599, 5.5945527674489, 20.72772973552502, 0.5180206902506798, 2.576019991890832, 2.0722967166990967, 9.89065739892874, 1.4294606029944341, 1.0548948811795307, 2.976596752883213, 2.739883279501856, 1.6324273664839068, 1.437120181277256, 12.837025805342078, 2.9271239870229535, 9.878980250603218, 3.996154371015824, 0.25956390233075954, 36.19846793612559, 9.04028533506228, 17.368236745173213, 13.043308767026746, 9.442312328428688, 0.9094749025762539, 3. ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(range(len(population)), population)
plt.show()

# %%
plt.hist(population, bins=20)
plt.show()

# %%
def g(**something):
  print(something.get('a') + something.get('b'))

# %%
g(a = 1,b = 2)
# Out:
# 3

# %%
import numpy as np
from scipy.stats import norm

# %%
mu = 65
sigma = 2.5

x = 64.5
n = 20

z = (x-mu)/(sigma/np.sqrt(n))

# %%
z
# Out:
# np.float64(-0.8944271909999159)

# %%
1-norm.pdf(z)
# Out:
# np.float64(0.7325809922357487)

# %%
norm.cdf(z)
# Out:
# np.float64(0.18554668476134878)

# %%
mu = 500
sigma = 125

x = 530
n = 70

z = (x-mu)/(sigma/np.sqrt(n))

# %%
z
# Out:
# np.float64(2.007984063681781)

# %%
1-norm.cdf(z)
# Out:
# np.float64(0.022322492581293485)

# %%
mu = 1.7
sigma = 0.5

x = 1.85
n = 30

z = (x-mu)/(sigma/np.sqrt(n))

# %%
z
# Out:
# np.float64(1.6431676725155)

# %%
z_critical = norm.ppf(1-0.02)

# %%
z_critical
# Out:
# np.float64(2.0537489106318225)

# %%
norm.cdf(4.167)
# Out:
# np.float64(0.9999845682751086)

# %%
1-norm.cdf(4.714)
# Out:
# np.float64(1.2145033095878333e-06)

# %%
norm.cdf(-1.74)*2
# Out:
# np.float64(0.08185901795761473)

# %%
from scipy.stats import norm
1-norm.cdf(1.86)
# Out:
# np.float64(0.03144276298075266)

# %%
1-norm.cdf(3.125)
# Out:
# np.float64(0.0008890252991083925)

# %%
from scipy.stats import norm

# %%
2 * (1-norm.cdf(2.53))
# Out:
# np.float64(0.01140625266590134)

# %%
def z_stat_prop(p_observered, p,n):
  import math
  return (p_observered-p)/math.sqrt(p*(1-p)/n)

# %%
z_stat_prop(0.6, 0.5, 100)
# Out:
# 1.9999999999999996

# %%
2 * (1-norm.cdf(abs(z_stat_prop(0.6, 0.5, 100))))
# Out:
# np.float64(0.04550026389635842)

# %%
1-norm.ppf(0.9)
# Out:
# np.float64(-0.28155156554460037)

# %%
z_stat_prop(0.66, 0.6, 750)
# Out:
# 3.354101966249688

# %%
print("z-proportion test")
# Out:
# z-proportion test

# %%
z_stat_prop(0.66, 0.6, 750)

# %%
print("Two sample Z proportion test")
# Out:
# Two sample Z proportion test

# %%
from scipy.stats import norm
def two_sample_z_stat_prop(p_not, p_1,p_2,n_1, n_2):
  import math
  return (p_1-p_2)/math.sqrt(p_not*(1-p_not)*(1/n_1 + 1/n_2))

# %%
z_st = two_sample_z_stat_prop(0.49, 0.5, 0.48, 150, 300)
print(z_st)
# Out:
# 0.40008002400800313

# %%
2*(1-norm.cdf(abs(z_st)))
# Out:
# np.float64(0.6890975768174321)

# %%
1-norm.cdf(0.467)
# Out:
# np.float64(0.32024993903580845)

# %%
data = [193, 321, 222, 158, 176, 149, 154, 223, 233, 177,
        280, 244, 138, 210, 167, 129, 254, 167, 194, 191,
        128, 191, 144, 184, 330, 216, 212, 142, 216, 197,
        231, 133, 205, 192, 195, 243, 224, 137, 234, 171,
        176, 249, 222, 234, 191]

# %%
import numpy as np

d = np.array(data)

# %%
d.mean()
# Out:
# np.float64(199.48888888888888)

# %%
d.std()
# Out:
# np.float64(45.980006390324924)

# %%
len(data)
# Out:
# 45

# %%
from scipy.stats import t

# %%
1-t.cdf(1.383, 45-1)
# Out:
# np.float64(0.08682165312980161)

# %%
1-t.cdf(1.383, 45-1)

# %%
def t_stat_calculation_right_tailed(data, mean, samples):
  import numpy, math
  from scipy.stats import t

  data = numpy.array(data)

  t_stat = (data.mean() - mean)*math.sqrt(samples)/data.std()

  return round(float(t_stat), 3), round(float(1-t.cdf(t_stat, samples-1)), 3)

# %%
t_stat_calculation_right_tailed(data=[14.3,12.6,13.7,10.9,13.7,12.0,11.4,12.0,12.6,13.1], mean=12, samples=10)
# Out:
# (1.935, 0.042)
